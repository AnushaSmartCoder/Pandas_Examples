# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/gapminder.tsv" ,sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.info()  ### The info() method gives the detailed information of dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 66.6+ KB

# %%
df.shape  #by using this shape we can find the number of rows and columns
# Out:
# (1704, 6)

# %%
df.head(5)  # Here i,m retriving the only head of rows means the starting five rows of data
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.sample
# Out:
# <bound method NDFrame.sample of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.sample(2)
# Out:
#                   country continent  year  lifeExp      pop    gdpPercap
# 1555  Trinidad and Tobago  Americas  1987   69.582  1191336  7388.597823
# 936              Malaysia      Asia  1952   48.463  6748378  1831.132894

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[[12,34,99,999],["country","pop","year"]]
# Out:
#         country       pop  year
# 12      Albania   1282697  1952
# 34      Algeria  31287142  2002
# 99   Bangladesh  62821884  1967
# 999    Mongolia   1149500  1967

# %%
df.iloc[4,4]
# Out:
# 13079460

# %%
df.iloc[2:9,5:10]
# Out:
#     gdpPercap
# 2  853.100710
# 3  836.197138
# 4  739.981106
# 5  786.113360
# 6  978.011439
# 7  852.395945
# 8  649.341395

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df["lifeExp"]
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64

# %%
import pandas as pd
s={"name":["s","a","n","d","y"],"roll.no":[2,34,5,23,5],"marks":[90,80,99,100,92]}
df=pd.DataFrame(s)
print(df)
# Out:
#   name  roll.no  marks
# 0    s        2     90
# 1    a       34     80
# 2    n        5     99
# 3    d       23    100
# 4    y        5     92

# %%
s={"name":["s","a","n","d","y"],"roll.no":[2,34,5,23,5],"marks":[90,80,99,100,92]}
sr=pd.DataFrame(s)
sr
# Out:
#   name  roll.no  marks
# 0    s        2     90
# 1    a       34     80
# 2    n        5     99
# 3    d       23    100
# 4    y        5     92

# %%
df
# Out:
#   name  roll.no  marks
# 0    s        2     90
# 1    a       34     80
# 2    n        5     99
# 3    d       23    100
# 4    y        5     92

# %%
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/gapminder.tsv" ,sep="\t")

# %%
# here i,m reading the csv file csv means comma seperated files

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns.unique()   # by using the unique() we can find the different kind of vlues means unique values
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
len(df.columns.unique())
# Out:
# 6

# %%
df.iloc[[2,3,2]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[1]  # here i,m retriving the only only 1 row of data
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
row=df.loc[0]  # here i,m retriving the data from only first row of data
row
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
type(row)
# Out:
# pandas.core.series.Series

# %%
len(df)
# Out:
# 1704

# %%
# using this len() function we can find the length of dataframe.

# %%
df.iloc[2:10,1:5]
# Out:
#   continent  year  lifeExp       pop
# 2      Asia  1962   31.997  10267083
# 3      Asia  1967   34.020  11537966
# 4      Asia  1972   36.088  13079460
# 5      Asia  1977   38.438  14880372
# 6      Asia  1982   39.854  12881816
# 7      Asia  1987   40.822  13867957
# 8      Asia  1992   41.674  16317921
# 9      Asia  1997   41.763  22227415

# %%
df.loc[2:9:3,"year":"pop"]
# Out:
#    year  lifeExp       pop
# 2  1962   31.997  10267083
# 5  1977   38.438  14880372
# 8  1992   41.674  16317921

# %%
df[df["year"]==1972]  ##here it will gives the only year 1972 rows of values
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 4            Afghanistan      Asia  1972   36.088  13079460   739.981106
# 16               Albania    Europe  1972   67.690   2263554  3313.422188
# 28               Algeria    Africa  1972   54.518  14760787  4182.663766
# 40                Angola    Africa  1972   37.928   5894858  5473.288005
# 52             Argentina  Americas  1972   67.065  24779799  9443.038526
# ...                  ...       ...   ...      ...       ...          ...
# 1648             Vietnam      Asia  1972   50.254  44655014   699.501644
# 1660  West Bank and Gaza      Asia  1972   56.532   1089572  3133.409277
# 1672         Yemen, Rep.      Asia  1972   39.848   7407075  1265.047031
# 1684              Zambia    Africa  1972   50.107   4506497  1773.498265
# 1696            Zimbabwe    Africa  1972   55.635   5861135   799.362176
#
# [142 rows x 6 columns]

# %%
df.iloc[2:9,2:6]
# Out:
#    year  lifeExp       pop   gdpPercap
# 2  1962   31.997  10267083  853.100710
# 3  1967   34.020  11537966  836.197138
# 4  1972   36.088  13079460  739.981106
# 5  1977   38.438  14880372  786.113360
# 6  1982   39.854  12881816  978.011439
# 7  1987   40.822  13867957  852.395945
# 8  1992   41.674  16317921  649.341395

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df[df['year']==1987]
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 7            Afghanistan      Asia  1987   40.822  13867957   852.395945
# 19               Albania    Europe  1987   72.000   3075321  3738.932735
# 31               Algeria    Africa  1987   65.799  23254956  5681.358539
# 43                Angola    Africa  1987   39.906   7874230  2430.208311
# 55             Argentina  Americas  1987   70.774  31620918  9139.671389
# ...                  ...       ...   ...      ...       ...          ...
# 1651             Vietnam      Asia  1987   62.820  62826491   820.799445
# 1663  West Bank and Gaza      Asia  1987   67.046   1691210  5107.197384
# 1675         Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538
# 1687              Zambia    Africa  1987   50.821   7272406  1213.315116
# 1699            Zimbabwe    Africa  1987   62.351   9216418   706.157306
#
# [142 rows x 6 columns]

# %% [markdown]
# Explanation:Here only i,m retriving only 1987 row of data

# %%
sns.pairplot(df,hue="country")

# %%
df[['country',"pop","year"]]
# Out:
#           country       pop  year
# 0     Afghanistan   8425333  1952
# 1     Afghanistan   9240934  1957
# 2     Afghanistan  10267083  1962
# 3     Afghanistan  11537966  1967
# 4     Afghanistan  13079460  1972
# ...           ...       ...   ...
# 1699     Zimbabwe   9216418  1987
# 1700     Zimbabwe  10704340  1992
# 1701     Zimbabwe  11404948  1997
# 1702     Zimbabwe  11926563  2002
# 1703     Zimbabwe  12311143  2007
#
# [1704 rows x 3 columns]

# %% [markdown]
# Explanation:Here only i,m retriving only 3 columns of data that is country,pop,year

# %%
df.iloc[0:10,[0,1,2]]
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
# 5  Afghanistan      Asia  1977
# 6  Afghanistan      Asia  1982
# 7  Afghanistan      Asia  1987
# 8  Afghanistan      Asia  1992
# 9  Afghanistan      Asia  1997

# %% [markdown]
# Explanation:Here only i,m retriving ten rows of data and 3 coumns of data i.e country,continent,year

# %%
df.loc[4,["year","pop"]]
# Out:
# year        1972
# pop     13079460
# Name: 4, dtype: object

# %%
df.loc[3,['continent']]
# Out:
# continent    Asia
# Name: 3, dtype: object

# %%
df.iloc[3,2:5]
# Out:
# year           1967
# lifeExp       34.02
# pop        11537966
# Name: 3, dtype: object

# %% [markdown]
# Explanation:iloc can take only index values

# %%
df.year.mode()
# Out:
# 0     1952
# 1     1957
# 2     1962
# 3     1967
# 4     1972
# 5     1977
# 6     1982
# 7     1987
# 8     1992
# 9     1997
# 10    2002
# 11    2007
# Name: year, dtype: int64

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.lifeExp.mean()
# Out:
# 59.474439366197174

# %% [markdown]
# Explanation:it is used to find the mean value of the lifeExp.

# %%
df.lifeExp.mode()
# Out:
# 0    69.39
# Name: lifeExp, dtype: float64

# %% [markdown]
# Explanation:  mode() it is used to find the repeated values.

# %%
df.lifeExp.max()
# Out:
# 82.603

# %% [markdown]
# Explanation:max() function is used to find the maximum value.

# %%
df.lifeExp.min()
# Out:
# 23.599

# %% [markdown]
# Explanation:  min() function is used to find the minimum value.

# %%
df.year.sort_values(ascending=True)
# Out:
# 0       1952
# 528     1952
# 540     1952
# 1656    1952
# 552     1952
#         ...
# 1127    2007
# 1139    2007
# 1151    2007
# 1175    2007
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df.lifeExp.sort_values(ascending=True)
# Out:
# 1292    23.599
# 0       28.801
# 552     30.000
# 36      30.015
# 1344    30.331
#          ...
# 1487    81.701
# 695     81.757
# 802     82.000
# 671     82.208
# 803     82.603
# Name: lifeExp, Length: 1704, dtype: float64

# %% [markdown]
# Explanation:   Sort_values() is used to sorting the values ascending and descending order..

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 66.6+ KB

# %%
sns.displot(df['country'],kde=False,bins=10)

# %% [markdown]
# ## displot:

# %%
sns.displot(df['continent'])

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df,hue="continent")

# %%
plt.figure(figsize=(10,12))
sns.heatmap(df.corr(),annot=True,cmap="tab20")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,8))
df.plot.hexbin(x="pop",y="lifeExp",gridsize=10)
# Out:
# <AxesSubplot:xlabel='pop', ylabel='lifeExp'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## countplot

# %%
plt.figure(figsize=(5,9))
sns.countplot("continent",data=df)
# Out:
# C:\Users\SRAM4\AppData\Local\Programs\Python\Python39-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot("lifeExp",data=df)
# Out:
# C:\Users\SRAM4\AppData\Local\Programs\Python\Python39-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lifeExp', ylabel='count'>

# %%
sns.displot(df["gdpPercap"])
